# %% [markdown]
# # Internal States — Data Download
#
# Downloads *some* QA CSVs from [ApolloResearch/deception-detection](https://github.com/ApolloResearch/deception-detection/tree/main/data/geometry_of_truth) data/intenral, concatenates them into a single CSV with an `origin_file` column, and saves to `data/`.
#
# We select those that we think do not appear in Geometry of Truth QA (*tbc*).

# %%
import io
import urllib.request
from pathlib import Path

import pandas as pd

# %%
BASE_URL = "https://raw.githubusercontent.com/ApolloResearch/deception-detection/main/data/internal_state/"

CSV_FILES = [
    "animals_true_false_qa.csv",
    "cities_true_false_qa.csv",
    "elements_true_false_qa.csv",
    "inventions_true_false_qa.csv",
]

# %%
frames = []

for filename in CSV_FILES:
    url = BASE_URL + filename
    print(f"Downloading {filename} ...", end=" ")
    with urllib.request.urlopen(url) as response:
        content = response.read().decode("utf-8")
    df = pd.read_csv(io.StringIO(content))
    df.insert(0, "origin_file", filename)
    frames.append(df)
    print(f"{len(df)} rows")

combined = pd.concat(frames, ignore_index=True)
print(f"\nTotal rows: {len(combined)}")
combined.head()
# Out:
# Downloading animals_true_false_qa.csv ... 1000 rows
# Downloading cities_true_false_qa.csv ... 1000 rows
# Downloading elements_true_false_qa.csv ... 930 rows
# Downloading inventions_true_false_qa.csv ... 876 rows
#
# Total rows: 3806
#                  origin_file  \
# 0  animals_true_false_qa.csv
# 1  animals_true_false_qa.csv
# 2  animals_true_false_qa.csv
# 3  animals_true_false_qa.csv
# 4  animals_true_false_qa.csv
#
#                                            statement  label  \
# 0             The dog has the atomic number of bird.      0
# 1  Human uses for slug include conservation, rese...      0
# 2  The giant anteater has the atomic number of fish.      0
# 3          The hedgehog uses walking for locomotion.      1
# 4        The sea turtle uses walking for locomotion.      0
#
#                                             question  \
# 0              What is the atomic number of the dog?
# 1                What are some human uses for slugs?
# 2   What is the atomic number of the giant anteater?
# 3        What method of locomotion do hedgehogs use?
# 4  What method of locomotion do sea turtles prima...
#
#                                       correct_answer  \
# 0  The dog does not have an atomic number, as dog...
# 1                       Conservation, research, zoos
# 2  The giant anteater does not have an atomic num...
# 3                                            Walking
# 4                                           Swimming
#
#                                 plausible_answer
# 0                                             17
# 1               Cooking, gardening, pest control
# 2  The giant anteater has an atomic number of 3.
# 3                                        Running
# 4                                        Walking

# %%
out_path = Path("../data/internal_state_qa.csv")
out_path.parent.mkdir(parents=True, exist_ok=True)
combined.to_csv(out_path, index=False)
print(f"Saved to {out_path.resolve()}")
# Out:
# Saved to /Users/fletcaw1/Documents/Personal/personal-repos/SPAR-causal-probes/data/internal_state_qa.csv
